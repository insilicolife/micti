# %% [markdown]
# # MICTI tutorial

# %% [markdown]
# We collected single-cell RNA-Seq dataset from six different immune cell types. We performed TPM normaization for each of the cells.

# %%
import pandas as pa
#%matplotlib notebook

# %%
datamatrix=pa.read_csv("data/dataset.txt", sep="\t", index_col="genes")

# %%
datamatrix.shape
# Out:
# (13888, 1153)

# %%
datamatrix.iloc[:10,:10]
# Out:
#          GSM2181141  GSM2181122  GSM2181113  GSM2180862  GSM2181258  \
# genes
# A1BG       0.000000    0.043549    0.054509    0.000000    0.000000
# A1CF       0.000000    0.000000    0.000000    0.000000    0.000000
# A2M        0.000000    0.000000    0.000000    0.000000    0.000000
# A2ML1      0.046830    0.071208    0.018045    0.000000    0.000000
# A4GALT     0.000000    0.000000    0.000000    0.000000    0.000000
# AAAS      39.244719    4.173193   28.947780    0.000000   67.050516
# AACS       0.623697    0.401357    0.362420    0.777686    0.270946
# AADACL3    0.000000    0.000000    0.000000    0.000000    0.000000
# AADAT      0.000000    0.000000    0.000000    0.000000    0.000000
# AAED1      8.078604    8.696563    6.825583    4.692559    0.904554
#
#          GSM2181201  GSM2180840  GSM2181133  GSM2181089  GSM2180853
# genes
# A1BG       0.066542    0.605715    0.651164    0.095305    0.000000
# A1CF       0.000000    0.000000    0.000000    0.000000    0.000000
# A2M        0.000000    0.000000    0.000000    0.000000    0.000000
# A2ML1      0.023222    0.531418    0.050903    0.098627    0.000000
# A4GALT     0.000000    0.000000    0.000000    0.000000    0.000000
# AAAS      97.502654    0.000000    2.375844   88.972850  341.262077
# AACS       0.893264    0.860927    0.546757    1.002484    0.000000
# AADACL3    0.000000    0.000000    0.000000    0.000000    0.000000
# AADAT      0.000000    0.000000    0.000000    0.000000    0.000000
# AAED1      0.456029    6.191677   12.625448   11.592398   10.103919

# %% [markdown]
# More information about the samples can be found from the metadata information. Metadata information contains disease stages, tissue catagory, sample source and other important information about the sample/cell. From the metadata table we extracted cell types/sample source in order to classify our cells according to cell type.

# %%
metadata=pa.read_csv("data/metadata.txt", sep="\t", index_col="SampleID")

# %%
metadata.iloc[:5,1:10]
# Out:
#            SubjectID     DiseaseCategory        TissueCategory  \
# SampleID
# GSM2181141   No Info  hematologic cancer  hematopoietic system
# GSM2181122   No Info  hematologic cancer  hematopoietic system
# GSM2181113   No Info  hematologic cancer  hematopoietic system
# GSM2180862   No Info  hematologic cancer  hematopoietic system
# GSM2181258   No Info  hematologic cancer  hematopoietic system
#
#                     BamFileName     CellType  \
# SampleID
# GSM2181141  EGAX00001437341.bam  lymphoblast
# GSM2181122  EGAX00001437284.bam  lymphoblast
# GSM2181113  EGAX00001437257.bam  lymphoblast
# GSM2180862  EGAX00001437608.bam       B cell
# GSM2181258  EGAX00001439870.bam       B cell
#
#                                          Description DiseaseStage  \
# SampleID
# GSM2181141  processed data file = cell_line_FPKM.csv      No Info
# GSM2181122  processed data file = cell_line_FPKM.csv      No Info
# GSM2181113  processed data file = cell_line_FPKM.csv      No Info
# GSM2180862  processed data file = cell_line_FPKM.csv      No Info
# GSM2181258  processed data file = cell_line_FPKM.csv      No Info
#
#                               DiseaseState Ethnicity
# SampleID
# GSM2181141  chronic myeloid leukemia (CML)   No Info
# GSM2181122  chronic myeloid leukemia (CML)   No Info
# GSM2181113  chronic myeloid leukemia (CML)   No Info
# GSM2180862                 B-cell lymphoma   No Info
# GSM2181258                 B-cell lymphoma   No Info

# %% [markdown]
# Now we have cell-type information for each of our samples/cells from the metadata table. So we wanted to get markers for each of the cell-types using MICTI

# %%
cell_type=list(metadata["CellType"])

# %%
geneName=list(datamatrix.index)
cellName=list(datamatrix.columns)

# %%
datamatrix.shape
# Out:
# (13888, 1153)

# %%
print(geneName[:10])
# Out:
# ['A1BG', 'A1CF', 'A2M', 'A2ML1', 'A4GALT', 'AAAS', 'AACS', 'AADACL3', 'AADAT', 'AAED1']

# %%
print(cellName[:10])
# Out:
# ['GSM2181141', 'GSM2181122', 'GSM2181113', 'GSM2180862', 'GSM2181258', 'GSM2181201', 'GSM2180840', 'GSM2181133', 'GSM2181089', 'GSM2180853']

# %%
set(cell_type)
# Out:
# {'B cell',
#  'CD4+ memory T cell',
#  'CD8+ memory T cell',
#  'conventional dendritic cell',
#  'fibroblast',
#  'lymphoblast'}

# %%
import imp
import MICTI
imp.reload(MICTI)
from MICTI import MARKER
# Out:
# /usr/local/lib/python3.5/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# # Creating MICTI object for known cell-types

# %%
mictiObject=MARKER.MICTI(datamatrix.T, geneName, cellName, cluster_assignment=cell_type , k=None, th=0, normalized=True, ensembel=False, organisum="hsapiens")

# %% [markdown]
# Visualize the 2D T-SNE plot.

# %%
mictiObject.get_Visualization(dim=2, method="tsne")

# %% [markdown]
# # Markers by cluster number

# %% [raw]
# Get marker genes for each of the cell-types:
#     cluster-0 is B cell,
#     cluster-1 is CD4+,
#     cluster-2 is CD8+,
#     cluster-3 is dendritic cells,
#     cluster-4 is fibroblast cells and
#     cluster-5 is lymphoblast cells.

# %% [markdown]
#  cluster-1 is CD4+ Markers

# %%
sig_genes=mictiObject.get_markers_by_Pvalues_and_Zscore(1, threshold_pvalue=.01,threshold_z_score=0)
sig_genes
# Out:
#             Adj P-value   Z_scores       p_value
# CSF2       0.000000e+00  20.313988  0.000000e+00
# IL2RG      0.000000e+00  12.560409  0.000000e+00
# ATP9B      0.000000e+00  28.123272  0.000000e+00
# HIST1H2BK  0.000000e+00   9.118146  0.000000e+00
# PATL2      0.000000e+00   9.055203  0.000000e+00
# CTLA4      0.000000e+00   8.523849  0.000000e+00
# CCL20      0.000000e+00  11.984467  0.000000e+00
# MAP3K14    0.000000e+00  32.571130  0.000000e+00
# GZMB       0.000000e+00  17.080777  0.000000e+00
# GPR171     0.000000e+00  10.677701  0.000000e+00
# SF3B5      0.000000e+00  11.117257  0.000000e+00
# IFNG       0.000000e+00  10.360014  0.000000e+00
# CD52       0.000000e+00   8.398631  0.000000e+00
# RGS16      0.000000e+00   9.957040  0.000000e+00
# CD2        0.000000e+00   8.398913  0.000000e+00
# PSMB1      0.000000e+00  56.456317  0.000000e+00
# NKG7       0.000000e+00  25.769184  0.000000e+00
# CD3D       0.000000e+00  12.869196  0.000000e+00
# CABIN1     1.623029e-13   8.200858  2.220446e-16
# MRFAP1L1   4.625633e-13   8.066493  6.661338e-16
# HIST1H4C   4.345292e-12   7.786121  6.883383e-15
# DUSP6      4.345292e-12   7.791301  6.661338e-15
# CD69       3.727322e-11   7.504271  6.172840e-14
# RGS1       1.887515e-10   7.283158  3.261835e-13
# CD40LG     9.965464e-10   7.049631  1.793898e-12
# S100A6     4.964135e-09   6.817040  9.293455e-12
# GIMAP7     5.333641e-09   6.801281  1.036926e-11
# GPR174     5.859356e-09   6.782477  1.181322e-11
# DUSP2      1.147657e-08   6.679569  2.396461e-11
# RNF113A    2.451822e-08   6.562360  5.296275e-11
# ...                 ...        ...           ...
# NOP10      5.125818e-05   5.246501  1.550146e-07
# ARL4C      6.061840e-05   5.211137  1.876866e-07
# TSTD1      8.014179e-05   5.154797  2.539055e-07
# MAF        8.066929e-05   5.149354  2.613852e-07
# HIGD2A     1.085568e-04   5.089207  3.595631e-07
# MT2A       1.145253e-04   5.074959  3.875786e-07
# POP7       2.254333e-04   4.940519  7.791473e-07
# MEA1       3.114217e-04   4.873071  1.098766e-06
# TMEM208    6.481351e-04   4.719729  2.361592e-06
# TUBB4B     6.481351e-04   4.718140  2.380105e-06
# ABT1       8.013927e-04   4.670778  3.000606e-06
# POLE3      1.194826e-03   4.584087  4.559746e-06
# BST2       1.656573e-03   4.511365  6.441166e-06
# UTP3       1.687600e-03   4.503532  6.683324e-06
# MRPL17     2.235672e-03   4.439548  9.014807e-06
# HAX1       2.993028e-03   4.372482  1.228417e-05
# TMED4      3.904812e-03   4.310243  1.630754e-05
# NFKBIA     4.214474e-03   4.289542  1.790423e-05
# EID1       4.427333e-03   4.274842  1.912730e-05
# PMAIP1     5.540769e-03   4.220865  2.433661e-05
# GIMAP4     5.650900e-03   4.212757  2.522723e-05
# HSPA5      5.980491e-03   4.196315  2.712924e-05
# PPP1R11    6.112629e-03   4.187787  2.816880e-05
# TSPYL1     6.359348e-03   4.175267  2.976365e-05
# METTL18    6.391531e-03   4.170640  3.037450e-05
# BEX2       7.816882e-03   4.118357  3.815836e-05
# TSPYL2     7.816882e-03   4.117660  3.827390e-05
# CISH       8.252758e-03   4.101758  4.100233e-05
# NIP7       8.610018e-03   4.088606  4.339727e-05
# IFITM1     9.451668e-03   4.063608  4.832002e-05
#
# [71 rows x 3 columns]

# %% [markdown]
# Plot heatmap for all marker genes in across all cell-types

# %%
mictiObject.heatMap()

# %% [markdown]
# Plot of heatmap for markers spacific to cluster-0 or B cells

# %%
mictiObject.heatMap(cluster_marker=0)

# %% [markdown]
# The radar plot for the mean expression of marker genes in their corrosponding cell types scaled to 0-1

# %%
xx=mictiObject.get_Radar_plot()

# %% [markdown]
# # Enrichment results for significantlly cell-type spacific marker genes:

# %% [markdown]
# Get gene-over representation enrichment analysis result for cell-type marker genes we previously analyzed for CD4+ cell-type:

# %%
mictiObject.get_gene_list_over_representation_analysis(list(sig_genes.index))
# Out:
#                     query.number  significant   p.value  term.size  \
# term.id
# KEGG:04660                     1         True  0.000023        101
# REAC:R-HSA-1280215             1         True  0.000150        687
# KEGG:04658                     1         True  0.000222         90
# KEGG:05330                     1         True  0.001340         35
# KEGG:05323                     1         True  0.003120         86
# KEGG:04672                     1         True  0.004020         46
# KEGG:05320                     1         True  0.005600         50
# KEGG:04659                     1         True  0.008120        105
# KEGG:05166                     1         True  0.009830        253
# GO:0019221                     1         True  0.009930        757
# HP:0008070                     1         True  0.011400        248
# KEGG:05321                     1         True  0.013900         63
# HP:0011357                     1         True  0.014900        258
# GO:0071345                     1         True  0.015700       1054
# KEGG:05322                     1         True  0.022100        130
# GO:1990904                     1         True  0.025300        825
# HP:0004313                     1         True  0.028100        107
# HP:0002719                     1         True  0.035400        565
# GO:0034097                     1         True  0.039000       1137
# HP:0004332                     1         True  0.040600        197
# GO:0002376                     1         True  0.041600       3044
# KEGG:05340                     1         True  0.042400         36
# KEGG:05332                     1         True  0.046000         37
#
#                     query.size  overlap.size  recall  precision  \
# term.id
# KEGG:04660                  34             7   0.206      0.069
# REAC:R-HSA-1280215          45            14   0.311      0.020
# KEGG:04658                  34             6   0.176      0.067
# KEGG:05330                  34             4   0.118      0.114
# KEGG:05323                  34             5   0.147      0.058
# KEGG:04672                  34             4   0.118      0.087
# KEGG:05320                  34             4   0.118      0.080
# KEGG:04659                  34             5   0.147      0.048
# KEGG:05166                  34             7   0.206      0.028
# GO:0019221                  71            13   0.183      0.017
# HP:0008070                  14             7   0.500      0.028
# KEGG:05321                  34             4   0.118      0.063
# HP:0011357                  14             7   0.500      0.027
# GO:0071345                  71            15   0.211      0.014
# KEGG:05322                  34             5   0.147      0.038
# GO:1990904                  71            13   0.183      0.016
# HP:0004313                  14             5   0.357      0.047
# HP:0002719                  14             9   0.643      0.016
# GO:0034097                  71            15   0.211      0.013
# HP:0004332                  14             6   0.429      0.030
# GO:0002376                  71            26   0.366      0.009
# KEGG:05340                  34             3   0.088      0.083
# KEGG:05332                  34             3   0.088      0.081
#
#                                term.id domain  subgraph.number  \
# term.id
# KEGG:04660                  KEGG:04660    keg               11
# REAC:R-HSA-1280215  REAC:R-HSA-1280215    rea               12
# KEGG:04658                  KEGG:04658    keg                2
# KEGG:05330                  KEGG:05330    keg               16
# KEGG:05323                  KEGG:05323    keg               15
# KEGG:04672                  KEGG:04672    keg               10
# KEGG:05320                  KEGG:05320    keg               14
# KEGG:04659                  KEGG:04659    keg                5
# KEGG:05166                  KEGG:05166    keg               17
# GO:0019221                  GO:0019221     BP                6
# HP:0008070                  HP:0008070     hp                3
# KEGG:05321                  KEGG:05321    keg                9
# HP:0011357                  HP:0011357     hp                3
# GO:0071345                  GO:0071345     BP                6
# KEGG:05322                  KEGG:05322    keg                8
# GO:1990904                  GO:1990904     CC                7
# HP:0004313                  HP:0004313     hp                1
# HP:0002719                  HP:0002719     hp               20
# GO:0034097                  GO:0034097     BP                6
# HP:0004332                  HP:0004332     hp               13
# GO:0002376                  GO:0002376     BP                4
# KEGG:05340                  KEGG:05340    keg               18
# KEGG:05332                  KEGG:05332    keg               19
#
#                                                           term.name  \
# term.id
# KEGG:04660                        T cell receptor signaling pathway
# REAC:R-HSA-1280215              Cytokine Signaling in Immune system
# KEGG:04658                         Th1 and Th2 cell differentiation
# KEGG:05330                                      Allograft rejection
# KEGG:05323                                     Rheumatoid arthritis
# KEGG:04672             Intestinal immune network for IgA production
# KEGG:05320                               Autoimmune thyroid disease
# KEGG:04659                                Th17 cell differentiation
# KEGG:05166                  Human T-cell leukemia virus 1 infection
# GO:0019221                      cytokine-mediated signaling pathway
# HP:0008070                                              Sparse hair
# KEGG:05321                         Inflammatory bowel disease (IBD)
# HP:0011357                              Abnormality of hair density
# GO:0071345                   cellular response to cytokine stimulus
# KEGG:05322                             Systemic lupus erythematosus
# GO:1990904                                ribonucleoprotein complex
# HP:0004313                        Decreased antibody level in blood
# HP:0002719                                     Recurrent infections
# GO:0034097                                     response to cytokine
# HP:0004332                           Abnormal lymphocyte morphology
# GO:0002376                                    immune system process
# KEGG:05340                                 Primary immunodeficiency
# KEGG:05332                                Graft-versus-host disease
#
#                     relative.depth  \
# term.id
# KEGG:04660                       1
# REAC:R-HSA-1280215               1
# KEGG:04658                       1
# KEGG:05330                       1
# KEGG:05323                       1
# KEGG:04672                       1
# KEGG:05320                       1
# KEGG:04659                       1
# KEGG:05166                       1
# GO:0019221                       3
# HP:0008070                       2
# KEGG:05321                       1
# HP:0011357                       1
# GO:0071345                       2
# KEGG:05322                       1
# GO:1990904                       1
# HP:0004313                       1
# HP:0002719                       1
# GO:0034097                       1
# HP:0004332                       1
# GO:0002376                       1
# KEGG:05340                       1
# KEGG:05332                       1
#
#                                                          intersection
# term.id
# KEGG:04660                 MAP3K14,NFKBIA,CD40LG,IFNG,CTLA4,CSF2,CD3D
# REAC:R-HSA-1280215  MAP3K14,PSMB1,NFKBIA,CD40LG,IFNG,CISH,CCL20,MT...
# KEGG:04658                         NFKBIA,IFNG,IL2RG,CD3D,MAF,HLA-DRA
# KEGG:05330                                   GZMB,CD40LG,IFNG,HLA-DRA
# KEGG:05323                              IFNG,CCL20,CTLA4,CSF2,HLA-DRA
# KEGG:04672                               MAP3K14,CD40LG,CXCR4,HLA-DRA
# KEGG:05320                                  GZMB,CD40LG,CTLA4,HLA-DRA
# KEGG:04659                             NFKBIA,IFNG,IL2RG,CD3D,HLA-DRA
# KEGG:05166               MAP3K14,NFKBIA,IL2RG,POLE3,CSF2,CD3D,HLA-DRA
# GO:0019221          MAP3K14,NFKBIA,CD40LG,IFNG,CISH,CCL20,CXCR4,MT...
# HP:0008070                NFKBIA,RNF113A,SAT1,DUSP6,MAF,NOP10,HLA-DRA
# KEGG:05321                                     IFNG,IL2RG,MAF,HLA-DRA
# HP:0011357                NFKBIA,RNF113A,SAT1,DUSP6,MAF,NOP10,HLA-DRA
# GO:0071345          MAP3K14,HSPA5,NFKBIA,CD40LG,IFNG,CISH,CCL20,CX...
# KEGG:05322                     CD40LG,IFNG,HIST1H4C,HIST1H2BK,HLA-DRA
# GO:1990904          APEX1,MRPL51,RNF113A,UTP3,NIP7,HAX1,MRPL17,SF3...
# HP:0004313                           CD40LG,CXCR4,RNF113A,IL2RG,CTLA4
# HP:0002719          NFKBIA,CD40LG,CXCR4,RNF113A,HAX1,IL2RG,CTLA4,C...
# GO:0034097          MAP3K14,HSPA5,NFKBIA,CD40LG,IFNG,CISH,CCL20,CX...
# HP:0004332                      CD40LG,CXCR4,RNF113A,IL2RG,CTLA4,CD3D
# GO:0002376          MAP3K14,PSMB1,ITM2A,RGS1,GZMB,NFKBIA,CD40LG,IF...
# KEGG:05340                                          CD40LG,IL2RG,CD3D
# KEGG:05332                                          GZMB,IFNG,HLA-DRA

# %%
Top_n_Gene_List_Enrichment_results=mictiObject.get_gene_over_representation_for_topn_genes(topn=20)
# Out:
# Cluster B cell (174 cells)
# ['HLA-DRA', 'MS4A1', 'TUBB', 'HLA-DPA1', 'RPS18', 'HIST1H4C', 'HIST1H1C', 'IFI30', 'EEF1G', 'CD74', 'CCR7', 'RPL36A', 'NME1-NME2', 'RPL23A', 'RPS27', 'STMN1', 'HLA-B', 'TNFRSF17', 'H2AFZ', 'CLIC1']
#
# Cluster CD4+ memory T cell (393 cells)
# ['CSF2', 'NKG7', 'PSMB1', 'CD2', 'RGS16', 'CD52', 'IFNG', 'SF3B5', 'CD3D', 'GZMB', 'MAP3K14', 'CCL20', 'CTLA4', 'PATL2', 'HIST1H2BK', 'ATP9B', 'IL2RG', 'GPR171', 'CABIN1', 'MRFAP1L1']
#
# Cluster CD8+ memory T cell (263 cells)
# ['EGR1', 'NKG7', 'DUSP2', 'FOS', 'IFNG', 'ZFP36', 'CD3D', 'IL2RG', 'GZMB', 'HIST1H1E', 'GZMH', 'GPR171', 'CTSW', 'CD69', 'S100A6', 'HIST1H4C', 'SF3B5', 'RGS1', 'CXCR4', 'HIST1H1C']
#
# Cluster conventional dendritic cell (105 cells)
# ['TNFSF13B', 'CD74', 'LYZ', 'RPS27', 'RPS18', 'AIF1', 'FCER1A', 'HLA-DRB1', 'HLA-DRA', 'FCER1G', 'CST3', 'HLA-DMB', 'LGALS2', 'CPVL', 'S100A9', 'TYROBP', 'EEF1G', 'RGS2', 'RPL21', 'HLA-DQA1']
#
# Cluster fibroblast (159 cells)
# ['LGALS1', 'MTRNR2L10', 'FOS', 'MTRNR2L1', 'TUBB', 'LUM', 'TIMP1', 'RPS18', 'S100A6', 'COL1A2', 'COL1A1', 'AXL', 'EGR1', 'ADAM9', 'MT2A', 'THBS1', 'MTRNR2L3', 'MTRNR2L8', 'PSMB1', 'CRIM1']
#
# Cluster lymphoblast (59 cells)
# ['PRAME', 'RPS18', 'HBG2', 'GAGE12B', 'HBG1', 'HBA2', 'HBA1', 'CKB', 'NME1-NME2', 'GTSF1', 'NMU', 'TOMM6', 'HIST1H2BK', 'EEF1G', 'STMN1', 'RHOXF2', 'HIST1H1C', 'RHAG', 'ACSM3', 'CLIC1']

# %% [markdown]
# # MICTI on -GSE86469 human pancreatic islet cell signatures

# %%
GSE86469=MARKER.GeoMinner.GEOMinner("GSE86469")
# Out:
# {'GPL18573': {'title': 'Illumina NextSeq 500 (Homo sapiens)', None: '\n    ', 'organism': 'Homo sapiens', 'manufacture-protocol': '\n    ', 'submission-date': '2014-04-15', 'distribution': 'virtual', 'technology': 'high-throughput sequencing', 'accession': 'GPL18573', 'last-update-date': '2019-03-26', 'manufacturer': None, 'contact-ref': '\n  ', 'status': None, 'release-date': '2014-04-15'}}

# %%
metadata=pa.DataFrame(GSE86469.getSamples()).T
cell_type=[i.split("\n")[1] for i in pa.DataFrame(GSE86469.getSamples()).T.loc[:,"cell type"]]

# %%
metadata["cell type"]=cell_type

# %%
metadata.iloc[:10,:10]
# Out:
#               NaN                    tissue           race  \
# GSM2303146
#
# Pancreatic Islet
#
# White
#
# GSM2303147
#
# Pancreatic Islet
#
# White
#
# GSM2303148
#
# Pancreatic Islet
#
# White
#
# GSM2303149
#
# Pancreatic Islet
#
# White
#
# GSM2303150
#
# Pancreatic Islet
#
# White
#
# GSM2303151
#
# Pancreatic Islet
#
# White
#
# GSM2303152
#
# Pancreatic Islet
#
# White
#
# GSM2303153
#
# Pancreatic Islet
#
# White
#
# GSM2303154
#
# Pancreatic Islet
#
# White
#
# GSM2303155
#
# Pancreatic Islet
#
# White
#
#
#                                              extract-protocol  \
# GSM2303146
# Single Cell Processing on the C1 Single Cell ...
# GSM2303147
# Single Cell Processing on the C1 Single Cell ...
# GSM2303148
# Single Cell Processing on the C1 Single Cell ...
# GSM2303149
# Single Cell Processing on the C1 Single Cell ...
# GSM2303150
# Single Cell Processing on the C1 Single Cell ...
# GSM2303151
# Single Cell Processing on the C1 Single Cell ...
# GSM2303152
# Single Cell Processing on the C1 Single Cell ...
# GSM2303153
# Single Cell Processing on the C1 Single Cell ...
# GSM2303154
# Single Cell Processing on the C1 Single Cell ...
# GSM2303155
# Single Cell Processing on the C1 Single Cell ...
#
#            series_accsesion channel source             Sex  characteristics  \
# GSM2303146         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303147         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303148         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303149         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303150         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303151         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303152         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303153         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303154         GSE86469    None   None
# Female
#
# ACIW009
#
# GSM2303155         GSE86469    None   None
# Female
#
# ACIW009
#
#
#              cell type
# GSM2303146  None/Other
# GSM2303147        Beta
# GSM2303148        Beta
# GSM2303149        Beta
# GSM2303150  None/Other
# GSM2303151        Beta
# GSM2303152    Stellate
# GSM2303153        Beta
# GSM2303154        Beta
# GSM2303155        Beta

# %%
set(cell_type)
# Out:
# {'Acinar',
#  'Alpha',
#  'Beta',
#  'Delta',
#  'Ductal',
#  'Gamma/PP',
#  'None/Other',
#  'Stellate'}

# %%
data=pa.read_csv("data/GSE86469_GEO.islet.single.cell.processed.data.RSEM.raw.expected.counts.csv", sep=",", index_col="Unnamed: 0")

# %%
data.iloc[:10,:10]
# Out:
#                  10th_C10_S104  10th_C11_S96  10th_C13_S61  10th_C14_S53  \
# ENSG00000229483           0.00          0.00          0.00          0.00
# ENSG00000232849           0.00          0.00          0.00          0.00
# ENSG00000229558           0.00          0.00          0.00          0.00
# ENSG00000232977           0.00          0.00          1.64          1.64
# ENSG00000227893          22.02          2.04          6.92          5.64
# ENSG00000238230           0.00          0.00          0.00          0.00
# ENSG00000227640           0.00          0.00          0.00          0.00
# ENSG00000260962           0.00          0.00          0.00          0.00
# ENSG00000228741           0.00          0.00          0.00          0.00
# ENSG00000247400           0.00          0.00        120.00          0.00
#
#                  10th_C16_S105  10th_C17_S97  10th_C19_S62  10th_C1_S59  \
# ENSG00000229483           0.00          0.00          0.00         0.00
# ENSG00000232849           0.00          0.00          0.00         0.00
# ENSG00000229558           0.00          0.00          0.00         0.00
# ENSG00000232977           0.00          0.88          0.00         1.70
# ENSG00000227893           4.47          0.00         21.44         2.15
# ENSG00000238230           0.00          0.00          0.00         0.00
# ENSG00000227640           0.00          0.00          0.00         0.00
# ENSG00000260962           0.00          0.00          0.00         0.00
# ENSG00000228741           0.00          0.00          0.00         0.00
# ENSG00000247400           0.00          0.00          0.00         0.00
#
#                  10th_C20_S54  10th_C23_S98
# ENSG00000229483          0.00          0.00
# ENSG00000232849          0.00          0.00
# ENSG00000229558          0.00          0.00
# ENSG00000232977          2.49          2.98
# ENSG00000227893          0.33         13.04
# ENSG00000238230          0.00          0.00
# ENSG00000227640          0.00          0.00
# ENSG00000260962          0.00          0.00
# ENSG00000228741          0.00          0.00
# ENSG00000247400         78.00          0.00

# %%
gene_symbol=MARKER.normalize.ENSEMBLID_to_geneSymbol(list(data.index))

# %%
CellNames=list(data.columns)
GeneNamees=gene_symbol

# %%
mictiObject_1=MARKER.MICTI(data.T, GeneNamees, CellNames, cluster_assignment=cell_type , k=None, th=0, UMI=False,normalized=True, ensembel=False)#, organisum="hsapiens")

# %%
mictiObject_1.get_Visualization(dim=2, method="tsne")

# %%
set(cell_type)
# Out:
# {'Acinar',
#  'Alpha',
#  'Beta',
#  'Delta',
#  'Ductal',
#  'Gamma/PP',
#  'None/Other',
#  'Stellate'}

# %%
sig_genes_1=mictiObject_1.get_markers_by_Pvalues_and_Zscore(0, threshold_pvalue=.01,threshold_z_score=0)
sig_genes_1
# Out:
#           Adj P-value   Z_scores       p_value
# REG1A    0.000000e+00  86.540388  0.000000e+00
# CTRB1    0.000000e+00  17.715766  0.000000e+00
# CTRB2    0.000000e+00  27.586588  0.000000e+00
# AMY2A    0.000000e+00   9.653276  0.000000e+00
# PRSS3    0.000000e+00  10.941113  0.000000e+00
# REG1B    0.000000e+00  49.676978  0.000000e+00
# CPA2     0.000000e+00  16.925487  0.000000e+00
# PLA2G1B  0.000000e+00  12.898128  0.000000e+00
# CELA3A   0.000000e+00  40.416834  0.000000e+00
# CPB1     0.000000e+00  21.568604  0.000000e+00
# PRSS1    0.000000e+00  96.520689  0.000000e+00
# PNLIP    0.000000e+00  31.647237  0.000000e+00
# CELA3B   0.000000e+00  11.694674  0.000000e+00
# OLFM4    0.000000e+00  10.412257  0.000000e+00
# REG3A    0.000000e+00   8.785304  0.000000e+00
# CPA1     0.000000e+00  43.149083  0.000000e+00
# CLPS     1.088124e-10   7.488710  6.949996e-14
# SPINK1   2.577062e-09   7.053649  1.742828e-12

# %%
mictiObject_1.heatMap()

# %%
mictiObject_1.get_gene_list_over_representation_analysis(list(sig_genes_1.index))
# Out:
#                     query.number  significant       p.value  term.size  \
# term.id
# KEGG:04972                     1         True  7.720000e-19         96
# KEGG:04974                     1         True  1.030000e-11         90
# GO:0005615                     1         True  3.740000e-09       3385
# GO:0005576                     1         True  6.050000e-09       4453
# GO:0044421                     1         True  1.050000e-08       3598
# GO:0007586                     1         True  3.240000e-08        130
# REAC:R-HSA-196741              1         True  9.160000e-07         21
# REAC:R-HSA-196854              1         True  3.140000e-06        189
# GO:0070011                     1         True  6.900000e-06        694
# GO:0009235                     1         True  8.000000e-06         22
# GO:0008233                     1         True  9.640000e-06        721
# HP:0005213                     1         True  1.010000e-05          7
# HP:0100027                     1         True  3.450000e-05         10
# HP:0030247                     1         True  1.050000e-04         14
# GO:0004252                     1         True  1.450000e-04        249
# GO:0008236                     1         True  2.670000e-04        276
# GO:0017171                     1         True  2.960000e-04        281
# REAC:R-HSA-8935690             1         True  3.110000e-04         22
# GO:0033013                     1         True  5.220000e-04         60
# HP:0005206                     1         True  5.470000e-04          2
# REAC:R-HSA-8963743             1         True  5.890000e-04         27
# HP:0011227                     1         True  6.600000e-04         25
# GO:0016787                     1         True  6.970000e-04       2647
# HP:0002570                     1         True  1.050000e-03         29
# REAC:R-HSA-1592389             1         True  1.090000e-03         33
# REAC:R-HSA-196849              1         True  1.320000e-03        123
# HP:0002630                     1         True  1.560000e-03         33
# GO:0006767                     1         True  1.850000e-03         82
# KEGG:04975                     1         True  1.860000e-03         41
# GO:0006508                     1         True  2.470000e-03       1833
# ...                          ...          ...           ...        ...
# HPA:013010_10                  1         True  1.200000e-02       1477
# HPA:007030_10                  1         True  1.200000e-02       1475
# HPA:056020_10                  1         True  1.200000e-02       1475
# HPA:055010_10                  1         True  1.200000e-02       1477
# HPA:008020_10                  1         True  1.200000e-02       1477
# HPA:001040_10                  1         True  1.200000e-02       1475
# HPA:008010_10                  1         True  1.200000e-02       1476
# HPA:041010_10                  1         True  1.200000e-02       1477
# HPA:039010_10                  1         True  1.200000e-02       1476
# HPA:027010_10                  1         True  1.200000e-02       1475
# HPA:026020_10                  1         True  1.200000e-02       1476
# HPA:027020_10                  1         True  1.200000e-02       1477
# HPA:008030_10                  1         True  1.200000e-02       1476
# HPA:050010_10                  1         True  1.200000e-02       1477
# HPA:012010_10                  1         True  1.200000e-02       1476
# HPA:045010_10                  1         True  1.200000e-02       1477
# HPA:046010_10                  1         True  1.200000e-02       1476
# HPA:024020_10                  1         True  1.200000e-02       1476
# HPA:053010_10                  1         True  1.200000e-02       1476
# HPA:007020_10                  1         True  1.200000e-02       1475
# HPA:016010_10                  1         True  1.200000e-02       1475
# HP:0012090                     1         True  1.560000e-02         70
# HP:0004936                     1         True  1.630000e-02         71
# HP:0001733                     1         True  1.630000e-02         71
# GO:0004180                     1         True  1.860000e-02         44
# HP:0001977                     1         True  3.000000e-02         87
# HPA:032010_12                  1         True  4.150000e-02        861
# HPA:032010_03                  1         True  4.200000e-02        864
# REAC:R-HSA-1474228             1         True  4.260000e-02        111
# GO:0008235                     1         True  4.290000e-02         58
#
#                     query.size  overlap.size  recall  precision  \
# term.id
# KEGG:04972                  12            11   0.917      0.115
# KEGG:04974                  12             8   0.667      0.089
# GO:0005615                  18            17   0.944      0.005
# GO:0005576                  18            18   1.000      0.004
# GO:0044421                  18            17   0.944      0.005
# GO:0007586                  18             7   0.389      0.054
# REAC:R-HSA-196741           11             4   0.364      0.190
# REAC:R-HSA-196854           11             6   0.545      0.032
# GO:0070011                  18             9   0.500      0.013
# GO:0009235                  18             4   0.222      0.182
# GO:0008233                  18             9   0.500      0.012
# HP:0005213                   4             3   0.750      0.429
# HP:0100027                   4             3   0.750      0.300
# HP:0030247                   4             3   0.750      0.214
# GO:0004252                  18             6   0.333      0.024
# GO:0008236                  18             6   0.333      0.022
# GO:0017171                  18             6   0.333      0.021
# REAC:R-HSA-8935690          11             3   0.273      0.136
# GO:0033013                  18             4   0.222      0.067
# HP:0005206                   4             2   0.500      1.000
# REAC:R-HSA-8963743          11             3   0.273      0.111
# HP:0011227                   4             3   0.750      0.120
# GO:0016787                  18            12   0.667      0.005
# HP:0002570                   4             3   0.750      0.103
# REAC:R-HSA-1592389          11             3   0.273      0.091
# REAC:R-HSA-196849           11             4   0.364      0.033
# HP:0002630                   4             3   0.750      0.091
# GO:0006767                  18             4   0.222      0.049
# KEGG:04975                  12             3   0.250      0.073
# GO:0006508                  18            10   0.556      0.005
# ...                        ...           ...     ...        ...
# HPA:013010_10                5             5   1.000      0.003
# HPA:007030_10                5             5   1.000      0.003
# HPA:056020_10                5             5   1.000      0.003
# HPA:055010_10                5             5   1.000      0.003
# HPA:008020_10                5             5   1.000      0.003
# HPA:001040_10                5             5   1.000      0.003
# HPA:008010_10                5             5   1.000      0.003
# HPA:041010_10                5             5   1.000      0.003
# HPA:039010_10                5             5   1.000      0.003
# HPA:027010_10                5             5   1.000      0.003
# HPA:026020_10                5             5   1.000      0.003
# HPA:027020_10                5             5   1.000      0.003
# HPA:008030_10                5             5   1.000      0.003
# HPA:050010_10                5             5   1.000      0.003
# HPA:012010_10                5             5   1.000      0.003
# HPA:045010_10                5             5   1.000      0.003
# HPA:046010_10                5             5   1.000      0.003
# HPA:024020_10                5             5   1.000      0.003
# HPA:053010_10                5             5   1.000      0.003
# HPA:007020_10                5             5   1.000      0.003
# HPA:016010_10                5             5   1.000      0.003
# HP:0012090                   4             3   0.750      0.043
# HP:0004936                   4             3   0.750      0.042
# HP:0001733                   4             3   0.750      0.042
# GO:0004180                  18             3   0.167      0.068
# HP:0001977                   4             3   0.750      0.034
# HPA:032010_12                5             4   0.800      0.005
# HPA:032010_03                5             4   0.800      0.005
# REAC:R-HSA-1474228          11             3   0.273      0.027
# GO:0008235                  18             3   0.167      0.052
#
#                                term.id domain  subgraph.number  \
# term.id
# KEGG:04972                  KEGG:04972    keg                8
# KEGG:04974                  KEGG:04974    keg               43
# GO:0005615                  GO:0005615     CC                2
# GO:0005576                  GO:0005576     CC                2
# GO:0044421                  GO:0044421     CC                2
# GO:0007586                  GO:0007586     BP               75
# REAC:R-HSA-196741    REAC:R-HSA-196741    rea               15
# REAC:R-HSA-196854    REAC:R-HSA-196854    rea               15
# GO:0070011                  GO:0070011     MF               17
# GO:0009235                  GO:0009235     BP               20
# GO:0008233                  GO:0008233     MF               17
# HP:0005213                  HP:0005213     hp                6
# HP:0100027                  HP:0100027     hp               80
# HP:0030247                  HP:0030247     hp               72
# GO:0004252                  GO:0004252     MF               17
# GO:0008236                  GO:0008236     MF               17
# GO:0017171                  GO:0017171     MF               17
# REAC:R-HSA-8935690  REAC:R-HSA-8935690    rea               66
# GO:0033013                  GO:0033013     BP               20
# HP:0005206                  HP:0005206     hp                6
# REAC:R-HSA-8963743  REAC:R-HSA-8963743    rea               66
# HP:0011227                  HP:0011227     hp               88
# GO:0016787                  GO:0016787     MF               17
# HP:0002570                  HP:0002570     hp               13
# REAC:R-HSA-1592389  REAC:R-HSA-1592389    rea                1
# REAC:R-HSA-196849    REAC:R-HSA-196849    rea               15
# HP:0002630                  HP:0002630     hp               13
# GO:0006767                  GO:0006767     BP               20
# KEGG:04975                  KEGG:04975    keg               51
# GO:0006508                  GO:0006508     BP               69
# ...                                ...    ...              ...
# HPA:013010_10            HPA:013010_10    hpa               24
# HPA:007030_10            HPA:007030_10    hpa               27
# HPA:056020_10            HPA:056020_10    hpa               86
# HPA:055010_10            HPA:055010_10    hpa               16
# HPA:008020_10            HPA:008020_10    hpa               46
# HPA:001040_10            HPA:001040_10    hpa               61
# HPA:008010_10            HPA:008010_10    hpa               77
# HPA:041010_10            HPA:041010_10    hpa               90
# HPA:039010_10            HPA:039010_10    hpa               28
# HPA:027010_10            HPA:027010_10    hpa               68
# HPA:026020_10            HPA:026020_10    hpa               53
# HPA:027020_10            HPA:027020_10    hpa               54
# HPA:008030_10            HPA:008030_10    hpa               48
# HPA:050010_10            HPA:050010_10    hpa               76
# HPA:012010_10            HPA:012010_10    hpa               91
# HPA:045010_10            HPA:045010_10    hpa               59
# HPA:046010_10            HPA:046010_10    hpa               29
# HPA:024020_10            HPA:024020_10    hpa               47
# HPA:053010_10            HPA:053010_10    hpa               21
# HPA:007020_10            HPA:007020_10    hpa               39
# HPA:016010_10            HPA:016010_10    hpa               87
# HP:0012090                  HP:0012090     hp                6
# HP:0004936                  HP:0004936     hp               72
# HP:0001733                  HP:0001733     hp               80
# GO:0004180                  GO:0004180     MF               65
# HP:0001977                  HP:0001977     hp               72
# HPA:032010_12            HPA:032010_12    hpa               38
# HPA:032010_03            HPA:032010_03    hpa               38
# REAC:R-HSA-1474228  REAC:R-HSA-1474228    rea                1
# GO:0008235                  GO:0008235     MF               65
#
#                                                             term.name  \
# term.id
# KEGG:04972                                       Pancreatic secretion
# KEGG:04974                           Protein digestion and absorption
# GO:0005615                                        extracellular space
# GO:0005576                                       extracellular region
# GO:0044421                                  extracellular region part
# GO:0007586                                                  digestion
# REAC:R-HSA-196741        Cobalamin (Cbl, vitamin B12) transport an...
# REAC:R-HSA-196854                Metabolism of vitamins and cofactors
# GO:0070011               peptidase activity, acting on L-amino aci...
# GO:0009235                                cobalamin metabolic process
# GO:0008233                                         peptidase activity
# HP:0005213                                   Pancreatic calcification
# HP:0100027                                     Recurrent pancreatitis
# HP:0030247                                 Splanchnic vein thrombosis
# GO:0004252                         serine-type endopeptidase activity
# GO:0008236                             serine-type peptidase activity
# GO:0017171                                  serine hydrolase activity
# REAC:R-HSA-8935690                                          Digestion
# GO:0033013                             tetrapyrrole metabolic process
# HP:0005206                                      Pancreatic pseudocyst
# REAC:R-HSA-8963743                           Digestion and absorption
# HP:0011227                          Elevated C-reactive protein level
# GO:0016787                                         hydrolase activity
# HP:0002570                                                Steatorrhea
# REAC:R-HSA-1592389            Activation of Matrix Metalloproteinases
# REAC:R-HSA-196849       Metabolism of water-soluble vitamins and c...
# HP:0002630                                          Fat malabsorption
# GO:0006767                    water-soluble vitamin metabolic process
# KEGG:04975                               Fat digestion and absorption
# GO:0006508                                                proteolysis
# ...                                                               ...
# HPA:013010_10          endometrium 1; cells in endometrial stroma[...
# HPA:007030_10          cerebellum; cells in molecular layer[Suppor...
# HPA:056020_10          tonsil; non-germinal center cells[Supported...
# HPA:055010_10          thyroid gland; glandular cells[Supported,No...
# HPA:008020_10          cerebral cortex; glial cells[Supported,Not ...
# HPA:001040_10          adrenal gland; glandular cells[Supported,No...
# HPA:008010_10          cerebral cortex; endothelial cells[Supporte...
# HPA:041010_10          skeletal muscle; myocytes[Supported,Not det...
# HPA:039010_10          salivary gland; glandular cells[Supported,N...
# HPA:027010_10               lung; macrophages[Supported,Not detected]
# HPA:026020_10              liver; hepatocytes[Supported,Not detected]
# HPA:027020_10               lung; pneumocytes[Supported,Not detected]
# HPA:008030_10          cerebral cortex; neuronal cells[Supported,N...
# HPA:050010_10          spleen; cells in red pulp[Supported,Not det...
# HPA:012010_10          duodenum; glandular cells[Supported,Not det...
# HPA:045010_10          small intestine; glandular cells[Supported,...
# HPA:046010_10          smooth muscle; smooth muscle cells[Supporte...
# HPA:024020_10          kidney; cells in tubules[Supported,Not dete...
# HPA:053010_10            testis; Leydig cells[Supported,Not detected]
# HPA:007020_10          cerebellum; cells in granular layer[Support...
# HPA:016010_10          esophagus; squamous epithelial cells[Suppor...
# HP:0012090                         Abnormality of pancreas morphology
# HP:0004936                                          Venous thrombosis
# HP:0001733                                               Pancreatitis
# GO:0004180                                  carboxypeptidase activity
# HP:0001977                                        Abnormal thrombosis
# HPA:032010_12          pancreas; exocrine glandular cells[Supporte...
# HPA:032010_03          pancreas; exocrine glandular cells[Uncertai...
# REAC:R-HSA-1474228            Degradation of the extracellular matrix
# GO:0008235                               metalloexopeptidase activity
#
#                     relative.depth  \
# term.id
# KEGG:04972                       1
# KEGG:04974                       1
# GO:0005615                       3
# GO:0005576                       1
# GO:0044421                       2
# GO:0007586                       1
# REAC:R-HSA-196741                3
# REAC:R-HSA-196854                1
# GO:0070011                       3
# GO:0009235                       1
# GO:0008233                       2
# HP:0005213                       1
# HP:0100027                       2
# HP:0030247                       3
# GO:0004252                       5
# GO:0008236                       4
# GO:0017171                       2
# REAC:R-HSA-8935690               2
# GO:0033013                       1
# HP:0005206                       2
# REAC:R-HSA-8963743               1
# HP:0011227                       1
# GO:0016787                       1
# HP:0002570                       2
# REAC:R-HSA-1592389               2
# REAC:R-HSA-196849                2
# HP:0002630                       1
# GO:0006767                       2
# KEGG:04975                       1
# GO:0006508                       1
# ...                            ...
# HPA:013010_10                    1
# HPA:007030_10                    1
# HPA:056020_10                    1
# HPA:055010_10                    1
# HPA:008020_10                    1
# HPA:001040_10                    1
# HPA:008010_10                    1
# HPA:041010_10                    1
# HPA:039010_10                    1
# HPA:027010_10                    1
# HPA:026020_10                    1
# HPA:027020_10                    1
# HPA:008030_10                    1
# HPA:050010_10                    1
# HPA:012010_10                    1
# HPA:045010_10                    1
# HPA:046010_10                    1
# HPA:024020_10                    1
# HPA:053010_10                    1
# HPA:007020_10                    1
# HPA:016010_10                    1
# HP:0012090                       1
# HP:0004936                       2
# HP:0001733                       1
# GO:0004180                       1
# HP:0001977                       1
# HPA:032010_12                    1
# HPA:032010_03                    1
# REAC:R-HSA-1474228               1
# GO:0008235                       1
#
#                                                          intersection
# term.id
# KEGG:04972          PRSS3,CPA1,CELA3A,CPB1,CPA2,CTRB1,PLA2G1B,PNLI...
# KEGG:04974             PRSS3,CPA1,CELA3A,CPB1,CPA2,CTRB1,PRSS1,CELA3B
# GO:0005615          PRSS3,CPA1,OLFM4,REG1A,CELA3A,CPB1,CPA2,SPINK1...
# GO:0005576          PRSS3,CPA1,OLFM4,REG1A,CLPS,CELA3A,CPB1,CPA2,S...
# GO:0044421          PRSS3,CPA1,OLFM4,REG1A,CELA3A,CPB1,CPA2,SPINK1...
# GO:0007586                   PRSS3,CLPS,CTRB1,CTRB2,PNLIP,PRSS1,AMY2A
# REAC:R-HSA-196741                             PRSS3,CTRB1,CTRB2,PRSS1
# REAC:R-HSA-196854                  PRSS3,CLPS,CTRB1,CTRB2,PNLIP,PRSS1
# GO:0070011          PRSS3,CPA1,CELA3A,CPB1,CPA2,CTRB1,CTRB2,PRSS1,...
# GO:0009235                                    PRSS3,CTRB1,CTRB2,PRSS1
# GO:0008233          PRSS3,CPA1,CELA3A,CPB1,CPA2,CTRB1,CTRB2,PRSS1,...
# HP:0005213                                          CPA1,SPINK1,PRSS1
# HP:0100027                                          CPA1,SPINK1,PRSS1
# HP:0030247                                          CPA1,SPINK1,PRSS1
# GO:0004252                      PRSS3,CELA3A,CTRB1,CTRB2,PRSS1,CELA3B
# GO:0008236                      PRSS3,CELA3A,CTRB1,CTRB2,PRSS1,CELA3B
# GO:0017171                      PRSS3,CELA3A,CTRB1,CTRB2,PRSS1,CELA3B
# REAC:R-HSA-8935690                                   CLPS,PNLIP,AMY2A
# GO:0033013                                    PRSS3,CTRB1,CTRB2,PRSS1
# HP:0005206                                               SPINK1,PRSS1
# REAC:R-HSA-8963743                                   CLPS,PNLIP,AMY2A
# HP:0011227                                          CPA1,SPINK1,PRSS1
# GO:0016787          PRSS3,CPA1,CELA3A,CPB1,CPA2,CTRB1,CTRB2,PLA2G1...
# HP:0002570                                         SPINK1,PNLIP,PRSS1
# REAC:R-HSA-1592389                                  CTRB1,CTRB2,PRSS1
# REAC:R-HSA-196849                             PRSS3,CTRB1,CTRB2,PRSS1
# HP:0002630                                         SPINK1,PNLIP,PRSS1
# GO:0006767                                    PRSS3,CTRB1,CTRB2,PRSS1
# KEGG:04975                                         CLPS,PLA2G1B,PNLIP
# GO:0006508          PRSS3,CPA1,CELA3A,CPB1,CPA2,SPINK1,CTRB1,CTRB2...
# ...                                                               ...
# HPA:013010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:007030_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:056020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:055010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:008020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:001040_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:008010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:041010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:039010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:027010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:026020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:027020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:008030_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:050010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:012010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:045010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:046010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:024020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:053010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:007020_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HPA:016010_10                         PRSS3,CELA3A,REG3A,REG1B,CELA3B
# HP:0012090                                          CPA1,SPINK1,PRSS1
# HP:0004936                                          CPA1,SPINK1,PRSS1
# HP:0001733                                          CPA1,SPINK1,PRSS1
# GO:0004180                                             CPA1,CPB1,CPA2
# HP:0001977                                          CPA1,SPINK1,PRSS1
# HPA:032010_12                               PRSS3,CELA3A,REG1B,CELA3B
# HPA:032010_03                               PRSS3,CELA3A,REG1B,CELA3B
# REAC:R-HSA-1474228                                  CTRB1,CTRB2,PRSS1
# GO:0008235                                             CPA1,CPB1,CPA2
#
# [119 rows x 14 columns]

# %% [markdown]
# # MICTI on the simulated data

# %%
data_sim=pa.read_csv("data/scSimulated_data_withSymsim1.txt", sep="\t")
cell_type=list(pa.read_csv("data/scSimulated_Metadata_withSymsim1.txt", sep="\t")["pop"])

cellNames = ['_'.join(["cell", str(i)]) for i in range(data_sim.shape[1])]

geneNames=['_'.join(["gene", str(i)]) for i in range(data_sim.shape[0])]

# %% [markdown]
# Simulated dataset using SysSim R package for single cell RNA-seq data with 5000 genes and in 200 cells

# %%
mictiObject_2=MARKER.MICTI(data_sim.T, geneNames, cellNames, cluster_assignment=cell_type, k=None, th=0, ensembel=False, normalized=False, UMI=True, organisum="hsapiens")

# %%
mictiObject_2.get_Visualization(dim=2, method="tsne")

# %%
mictiObject_2.heatMap()
